# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
df = pd.read_csv('historic_groceries.csv')
df
# Out:
#       Month  Rice  Wheat  Barley  Corn  Peanuts   Sugar  Coconut-oil  \
# 0    Oct-90  0.28   0.11    0.09  0.10     2.12  0.0049         0.28
# 1    Nov-90  0.27   0.11    0.09  0.10     2.11  0.0049         0.34
# 2    Dec-90  0.26   0.11    0.09  0.10     2.00  0.0046         0.32
# 3    Jan-91  0.30   0.11    0.09  0.11     1.85  0.0042         0.34
# 4    Feb-91  0.33   0.11    0.09  0.11     1.79  0.0042         0.33
# ..      ...   ...    ...     ...   ...      ...     ...          ...
# 355  May-20  0.51   0.21    0.08  0.14     2.05  0.0053         0.83
# 356  Jun-20  0.52   0.20    0.08  0.15     2.05  0.0060         0.92
# 357  Jul-20  0.48   0.20    0.08  0.15     1.99  0.0060         0.89
# 358  Aug-20  0.50   0.20    0.08  0.15     1.30  0.0064         0.98
# 359  Sep-20  0.51   0.20    0.08  0.17     1.68  0.0062         1.03
#
#      Palm-oil  Sunflower-oil  Chicken    Beef    Pork  Fish   Tea  Coffee
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 360 entries, 0 to 359
# Data columns (total 16 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Month          360 non-null    object
#  1   Rice           360 non-null    float64
#  2   Wheat          360 non-null    float64
#  3   Barley         360 non-null    float64
#  4   Corn           360 non-null    float64
#  5   Peanuts        360 non-null    float64
#  6   Sugar          360 non-null    float64
#  7   Coconut-oil    360 non-null    float64
#  8   Palm-oil       360 non-null    float64
#  9   Sunflower-oil  219 non-null    float64
#  10  Chicken        360 non-null    float64
#  11  Beef           360 non-null    float64
#  12  Pork           321 non-null    float64
#  13  Fish           321 non-null    float64
#  14  Tea            360 non-null    float64
#  15  Coffee         360 non-null    float64
# dtypes: float64(15), object(1)
# memory usage: 43.7+ KB

# %%
df = df.drop('Sunflower-oil',axis=1)
df
# Out:
#       Month  Rice  Wheat  Barley  Corn  Peanuts   Sugar  Coconut-oil  \
# 0    Oct-90  0.28   0.11    0.09  0.10     2.12  0.0049         0.28
# 1    Nov-90  0.27   0.11    0.09  0.10     2.11  0.0049         0.34
# 2    Dec-90  0.26   0.11    0.09  0.10     2.00  0.0046         0.32
# 3    Jan-91  0.30   0.11    0.09  0.11     1.85  0.0042         0.34
# 4    Feb-91  0.33   0.11    0.09  0.11     1.79  0.0042         0.33
# ..      ...   ...    ...     ...   ...      ...     ...          ...
# 355  May-20  0.51   0.21    0.08  0.14     2.05  0.0053         0.83
# 356  Jun-20  0.52   0.20    0.08  0.15     2.05  0.0060         0.92
# 357  Jul-20  0.48   0.20    0.08  0.15     1.99  0.0060         0.89
# 358  Aug-20  0.50   0.20    0.08  0.15     1.30  0.0064         0.98
# 359  Sep-20  0.51   0.20    0.08  0.17     1.68  0.0062         1.03
#
#      Palm-oil  Chicken    Beef    Pork  Fish   Tea  Coffee
# 0        0.29   0.0236  0.0571  2.5051  6.35  1.60    1.24
# ...

# %%
df['month'] = df.Month.str.split('-').map(lambda x: x[0])
df['year'] = df.Month.str.split('-').map(lambda x: x[1])
df  = df.drop('Month',axis=1)
df
# Out:
#      Rice  Wheat  Barley  Corn  Peanuts   Sugar  Coconut-oil  Palm-oil  \
# 0    0.28   0.11    0.09  0.10     2.12  0.0049         0.28      0.29
# 1    0.27   0.11    0.09  0.10     2.11  0.0049         0.34      0.33
# 2    0.26   0.11    0.09  0.10     2.00  0.0046         0.32      0.35
# 3    0.30   0.11    0.09  0.11     1.85  0.0042         0.34      0.35
# 4    0.33   0.11    0.09  0.11     1.79  0.0042         0.33      0.34
# ..    ...    ...     ...   ...      ...     ...          ...       ...
# 355  0.51   0.21    0.08  0.14     2.05  0.0053         0.83      0.58
# 356  0.52   0.20    0.08  0.15     2.05  0.0060         0.92      0.66
# 357  0.48   0.20    0.08  0.15     1.99  0.0060         0.89      0.69
# 358  0.50   0.20    0.08  0.15     1.30  0.0064         0.98      0.76
# 359  0.51   0.20    0.08  0.17     1.68  0.0062         1.03      0.80
#
#      Chicken    Beef    Pork  Fish   Tea  Coffee month year
# ...

# %%
df = df.drop([0,1,2,351,352,353,354,355,356,357,358,359],axis=0)
df
# Out:
#      Rice  Wheat  Barley  Corn  Peanuts   Sugar  Coconut-oil  Palm-oil  \
# 3    0.30   0.11    0.09  0.11     1.85  0.0042         0.34      0.35
# 4    0.33   0.11    0.09  0.11     1.79  0.0042         0.33      0.34
# 5    0.31   0.12    0.09  0.11     1.70  0.0044         0.34      0.35
# 6    0.29   0.12    0.09  0.11     1.50  0.0042         0.32      0.32
# 7    0.29   0.12    0.09  0.11     1.26  0.0037         0.34      0.32
# ..    ...    ...     ...   ...      ...     ...          ...       ...
# 346  0.43   0.18    0.14  0.16     1.25  0.0060         0.72      0.59
# 347  0.43   0.19    0.11  0.16     1.32  0.0057         0.72      0.58
# 348  0.42   0.20    0.11  0.17     1.36  0.0062         0.72      0.59
# 349  0.42   0.20    0.11  0.17     1.40  0.0062         0.85      0.69
# 350  0.43   0.21    0.11  0.17     1.53  0.0066         1.03      0.76
#
#      Chicken    Beef    Pork  Fish   Tea  Coffee month year
# ...

# %%
sales_by_year = df.groupby('year').sum()
sales_by_year
# Out:
#       Rice  Wheat  Barley  Corn  Peanuts   Sugar  Coconut-oil  Palm-oil  \
# year
# 00    2.43   1.39    0.93  1.09    10.13  0.0475         5.40      3.73
# 01    2.06   1.51    1.12  1.07    10.00  0.0502         3.82      3.42
# 02    2.32   1.77    1.31  1.19     9.02  0.0401         5.05      4.68
# 03    2.39   1.76    1.25  1.29    11.70  0.0413         5.61      5.32
# 04    2.85   1.88    1.19  1.33    11.68  0.0419         7.93      5.66
# 05    3.44   1.81    1.14  1.20    10.65  0.0578         7.42      5.07
# 06    3.65   2.30    1.40  1.46    10.87  0.0866         7.28      5.74
# 07    3.92   3.08    2.07  1.96    15.14  0.0589        11.02      9.35
# 08    7.79   3.92    2.42  2.68    19.60  0.0748        14.68     11.38
# 09    6.65   2.68    1.53  1.97    13.92  0.1057         8.70      8.18
# 10    5.87   2.68    1.91  2.24    15.43  0.1240        13.47     10.81
# 11    6.52   3.82    2.50  3.49    25.04  0.1515        20.75     13.49
# ...

# %%
products = sales_by_year.columns
for product in products:
    plt.figure(figsize=(20,10))
    sns.barplot(x=sales_by_year.index,y=product,data=sales_by_year)
    plt.title(product)

# %%
avg_by_month = df.groupby('month').mean()
avg_by_month
# Out:
#            Rice     Wheat    Barley      Corn   Peanuts     Sugar  \
# month
# Apr    0.358276  0.192759  0.124138  0.152759  1.172414  0.006007
# Aug    0.351724  0.190345  0.119310  0.147586  1.150345  0.006266
# Dec    0.350345  0.196552  0.120345  0.146897  1.194138  0.006376
# Feb    0.358276  0.195172  0.118966  0.150000  1.182414  0.006397
# Jan    0.356207  0.194483  0.120000  0.148621  1.200690  0.006400
# Jul    0.358276  0.188621  0.125172  0.151379  1.165172  0.006286
# Jun    0.357586  0.190345  0.126552  0.154138  1.154483  0.006059
# Mar    0.354138  0.194483  0.121034  0.153793  1.185517  0.006203
# May    0.357241  0.192759  0.126552  0.154138  1.170345  0.005952
# Nov    0.344828  0.195172  0.119310  0.146552  1.186552  0.006317
# Oct    0.345517  0.195862  0.116552  0.145862  1.169310  0.006352
# Sep    0.348621  0.193448  0.114138  0.144828  1.166897  0.006207
#
#        Coconut-oil  Palm-oil   Chicken      Beef      Pork      Fish  \
# month
# ...

# %%
items = avg_by_month.columns
for item in items:
    plt.figure(figsize=(20,10))
    sns.barplot(x=avg_by_month.index,y=item,data=avg_by_month)
    plt.title(item)

# %%
from sklearn.preprocessing import LabelEncoder
labelencoder = LabelEncoder()
df['year'] = labelencoder.fit_transform(df['year'])
df
# Out:
#      Rice  Wheat  Barley  Corn  Peanuts   Sugar  Coconut-oil  Palm-oil  \
# 3    0.30   0.11    0.09  0.11     1.85  0.0042         0.34      0.35
# 4    0.33   0.11    0.09  0.11     1.79  0.0042         0.33      0.34
# 5    0.31   0.12    0.09  0.11     1.70  0.0044         0.34      0.35
# 6    0.29   0.12    0.09  0.11     1.50  0.0042         0.32      0.32
# 7    0.29   0.12    0.09  0.11     1.26  0.0037         0.34      0.32
# ..    ...    ...     ...   ...      ...     ...          ...       ...
# 346  0.43   0.18    0.14  0.16     1.25  0.0060         0.72      0.59
# 347  0.43   0.19    0.11  0.16     1.32  0.0057         0.72      0.58
# 348  0.42   0.20    0.11  0.17     1.36  0.0062         0.72      0.59
# 349  0.42   0.20    0.11  0.17     1.40  0.0062         0.85      0.69
# 350  0.43   0.21    0.11  0.17     1.53  0.0066         1.03      0.76
#
#      Chicken    Beef    Pork  Fish   Tea  Coffee month  year
# ...

# %%
df['month'] = labelencoder.fit_transform(df['month'])
df
# Out:
#      Rice  Wheat  Barley  Corn  Peanuts   Sugar  Coconut-oil  Palm-oil  \
# 3    0.30   0.11    0.09  0.11     1.85  0.0042         0.34      0.35
# 4    0.33   0.11    0.09  0.11     1.79  0.0042         0.33      0.34
# 5    0.31   0.12    0.09  0.11     1.70  0.0044         0.34      0.35
# 6    0.29   0.12    0.09  0.11     1.50  0.0042         0.32      0.32
# 7    0.29   0.12    0.09  0.11     1.26  0.0037         0.34      0.32
# ..    ...    ...     ...   ...      ...     ...          ...       ...
# 346  0.43   0.18    0.14  0.16     1.25  0.0060         0.72      0.59
# 347  0.43   0.19    0.11  0.16     1.32  0.0057         0.72      0.58
# 348  0.42   0.20    0.11  0.17     1.36  0.0062         0.72      0.59
# 349  0.42   0.20    0.11  0.17     1.40  0.0062         0.85      0.69
# 350  0.43   0.21    0.11  0.17     1.53  0.0066         1.03      0.76
#
#      Chicken    Beef    Pork  Fish   Tea  Coffee  month  year
# ...

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %%
df_train = df.iloc[:318,:] 
df_test = df.iloc[318:,:]

# %%
X_train,X_test,y_train,y_test = train_test_split(df_train.drop(df_train[['Pork','Fish']],axis=1),df_train['Pork'],test_size=0.2,random_state=0)
linear_regressor = LinearRegression()
linear_regressor.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
linear_regressor.coef_
# Out:
# array([-1.48416379e-02,  1.88066646e-01,  1.42086356e+00,  2.30416453e+00,
#         2.11618610e-01,  3.52865128e+01, -7.77220204e-02, -8.86103319e-01,
#         1.22671698e+01,  6.90971573e+00, -2.97874074e-01, -4.92687040e-02,
#        -4.29509220e-03,  1.04728427e-02])

# %%
prediction = linear_regressor.predict(X_test)
prediction
# Out:
# array([2.01430049, 1.98960208, 1.4389306 , 1.72432773, 1.62265526,
#        1.63390264, 1.58920776, 1.48715257, 1.42565654, 1.38320839,
#        1.65672245, 1.40561531, 1.403946  , 1.99373297, 1.50702578,
#        1.6029851 , 1.32717975, 2.14969328, 1.78195562, 1.46950135,
#        1.67355008, 1.24732823, 1.24620564, 1.45485365, 2.005004  ,
#        1.39771173, 1.56643007, 1.59308984, 1.65483955, 1.69598556,
#        1.43645114, 1.29218408, 1.85080579, 1.28396711, 1.39185515,
#        1.30354954, 1.4501383 , 1.00007417, 1.49423968, 1.27017038,
#        1.43031892, 1.31695395, 1.56108315, 1.2863164 , 1.44561008,
#        1.04043049, 1.79183703, 1.95627711, 1.35844026, 1.18795011,
#        2.1348291 , 1.42078982, 2.06171112, 1.26115419, 1.31335033,
#        1.49624507, 1.38601683, 1.19498103, 1.27001209, 1.39680494,
#        1.76298412, 1.56712716, 1.46846905, 2.12380923])

# %%
from sklearn.metrics import mean_squared_error,r2_score

print(mean_squared_error(y_test,prediction))
print(r2_score(y_test,prediction))
# Out:
# 0.08909334183313286
# 0.4526968650313127

# %%
plt.figure(figsize=(20,10))
sns.lineplot(range(0,64),prediction,color='b')
sns.lineplot(range(0,64),ridge_prediction,color='g')
sns.lineplot(range(0,64),y_test,color='r')
plt.xticks(range(0,64,1));

# %%
from sklearn.linear_model import Ridge

# %%
ridge_reg = Ridge()
ridge_reg.fit(X_train,y_train)
# Out:
# Ridge()

# %%
ridge_reg.coef_
# Out:
# array([ 0.35157643,  0.51089884,  0.26211251,  0.62660455,  0.36252104,
#         0.0272334 ,  0.11145232, -0.42999712,  0.12245413,  0.44055531,
#        -0.08832378, -0.01684093, -0.0034311 ,  0.00197273])

# %%
ridge_prediction = ridge_reg.predict(X_test)
ridge_prediction
# Out:
# array([2.09452056, 2.04739574, 1.410576  , 1.54580205, 1.69086519,
#        1.5598731 , 1.55321092, 1.40309669, 1.39578677, 1.54519144,
#        1.54694022, 1.3754144 , 1.34105211, 1.95068147, 1.58383526,
#        1.51489502, 1.33366826, 1.67577288, 1.56728801, 1.35180749,
#        1.57757804, 1.35893694, 1.23119022, 1.35003566, 1.57329931,
#        1.41790251, 1.6715719 , 1.4667191 , 1.53802379, 1.53175801,
#        1.5705342 , 1.31505968, 1.57490577, 1.30341531, 1.39168103,
#        1.37359923, 1.43128197, 1.30494336, 1.42263658, 1.35534621,
#        1.46868108, 1.3133412 , 1.49774863, 1.23102162, 1.43320138,
#        1.25122844, 1.80595474, 1.60732196, 1.3835242 , 1.33714217,
#        1.62731529, 1.42773367, 1.6800725 , 1.29311012, 1.27850277,
#        1.37862295, 1.414057  , 1.34038121, 1.36928029, 1.37699898,
#        1.74965547, 1.44024172, 1.55429412, 1.65008201])

# %%
print(r2_score(y_test, ridge_prediction))
# Out:
# 0.24261852765247627

# %%
plt.figure(figsize=(20,10))
sns.pairplot(df)

# %%
df_corr = df.corr()
df_corr
# Out:
#                  Rice     Wheat    Barley      Corn   Peanuts     Sugar  \
# Rice         1.000000  0.771244  0.757517  0.830536  0.716072  0.718462
# Wheat        0.771244  1.000000  0.900858  0.890470  0.633422  0.640641
# Barley       0.757517  0.900858  1.000000  0.913957  0.686790  0.622044
# Corn         0.830536  0.890470  0.913957  1.000000  0.767811  0.755218
# Peanuts      0.716072  0.633422  0.686790  0.767811  1.000000  0.665852
# Sugar        0.718462  0.640641  0.622044  0.755218  0.665852  1.000000
# Coconut-oil  0.650894  0.613306  0.534163  0.678784  0.664096  0.692489
# Palm-oil     0.799997  0.821168  0.805132  0.837959  0.745051  0.763652
# Chicken      0.670131  0.643966  0.620928  0.678759  0.570730  0.563132
# Beef         0.600973  0.538540  0.476056  0.632730  0.627027  0.588987
# Pork         0.382167  0.439314  0.415854  0.513858  0.431863  0.400832
# Fish         0.497449  0.426966  0.309557  0.482352  0.398839  0.620930
# ...

# %%
plt.figure(figsize=(20,10))
sns.heatmap(df_corr)

# %% [markdown]
# lets omit palm-oil, rice, and barley as they have high correlation with other components and may be creating noise

# %%
df2 = df.drop(df[['Rice','Barley','Palm-oil']],axis=1)
df2
# Out:
#      Wheat  Corn  Peanuts   Sugar  Coconut-oil  Chicken    Beef    Pork  Fish  \
# 3     0.11  0.11     1.85  0.0042         0.34   0.0231  0.0571  2.6495  6.34
# 4     0.11  0.11     1.79  0.0042         0.33   0.0238  0.0602  2.3517  6.41
# 5     0.12  0.11     1.70  0.0044         0.34   0.0236  0.0571  2.4224  5.78
# 6     0.12  0.11     1.50  0.0042         0.32   0.0234  0.0575  2.3735  5.37
# 7     0.12  0.11     1.26  0.0037         0.34   0.0234  0.0580  2.3574  5.05
# ..     ...   ...      ...     ...          ...      ...     ...     ...   ...
# 346   0.18  0.16     1.25  0.0060         0.72   0.0419  0.1014     NaN   NaN
# 347   0.19  0.16     1.32  0.0057         0.72   0.0408  0.1025     NaN   NaN
# 348   0.20  0.17     1.36  0.0062         0.72   0.0408  0.1071     NaN   NaN
# 349   0.20  0.17     1.40  0.0062         0.85   0.0408  0.1310     NaN   NaN
# 350   0.21  0.17     1.53  0.0066         1.03   0.0437  0.1226     NaN   NaN
#
#       Tea  Coffee  month  year
# ...

# %%
df2_train = df2.iloc[:318,:] 
df2_test = df2.iloc[318:,:]

# %%
X = df2_train.drop('Pork',axis=1)
y = df2_train.Pork

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2,random_state=0)

# %%
regressor_2 = LinearRegression()
regressor_2.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
regressor_2.coef_
# Out:
# array([-6.07137229e-01,  2.99943709e+00,  1.98282951e-01,  1.73646038e+01,
#        -3.79256894e-01,  1.26003544e+01,  6.87388785e+00,  5.05597694e-02,
#        -3.06965588e-01, -1.07157643e-01, -2.66588837e-03,  7.77898079e-03])

# %%
prediction_2 = regressor_2.predict(X_test)
prediction_2
# Out:
# array([1.92713156, 2.04824125, 1.42514121, 1.55183278, 1.49389297,
#        1.50401498, 1.65554014, 1.46176618, 1.37971904, 1.38196428,
#        1.51170253, 1.26480684, 1.30521675, 1.95978385, 1.60645947,
#        1.49781187, 1.27571424, 2.25155674, 1.61528816, 1.51232093,
#        1.77205745, 1.33115404, 1.27265522, 1.44940814, 1.9743324 ,
#        1.57997784, 1.50843864, 1.59785381, 1.65061734, 1.64927333,
#        1.44838234, 1.38100593, 1.90605376, 1.4330748 , 1.36196382,
#        1.3553416 , 1.42071884, 0.99773347, 1.45290424, 1.29577801,
#        1.52375416, 1.19099032, 1.46663842, 1.27209007, 1.49240948,
#        1.22824716, 1.73819076, 1.90541328, 1.29142777, 1.16423822,
#        2.09975315, 1.56069537, 1.93945009, 1.26855797, 1.28180608,
#        1.48130793, 1.36710446, 1.30168763, 1.32897658, 1.39999889,
#        1.87008613, 1.589569  , 1.44651207, 2.18541859])

# %%
regressor_2.score(X_test,y_test)
# Out:
# 0.3613964921096049
